# %% [markdown]
# # Setting up Vanilla U-Net to run on X-Ray Image segmentation

# %% [markdown]
# ## Part 1: Importing required libraries and data preparation

# %%
# !unzip MontgomerySet.zip
# Out:
# Archive:  MontgomerySet.zip
#   inflating: MontgomerySet/.DS_Store
#    creating: MontgomerySet/ClinicalReadings/
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0001_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0002_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0003_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0004_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0005_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0006_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0008_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0011_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0013_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0015_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0016_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0017_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0019_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0020_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0021_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0022_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0023_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0024_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0026_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0027_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0028_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0029_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0030_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0031_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0035_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0038_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0040_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0041_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0042_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0043_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0044_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0045_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0046_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0047_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0048_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0049_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0051_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0052_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0053_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0054_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0055_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0056_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0057_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0058_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0059_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0060_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0061_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0062_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0063_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0064_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0068_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0069_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0070_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0071_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0072_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0074_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0075_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0077_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0079_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0080_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0081_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0082_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0083_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0084_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0085_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0086_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0087_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0089_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0090_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0091_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0092_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0094_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0095_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0096_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0097_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0099_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0100_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0101_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0102_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0103_0.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0104_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0108_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0113_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0117_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0126_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0140_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0141_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0142_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0144_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0150_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0162_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0166_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0170_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0173_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0182_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0188_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0194_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0195_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0196_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0203_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0213_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0218_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0223_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0228_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0243_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0251_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0253_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0254_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0255_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0258_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0264_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0266_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0275_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0282_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0289_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0294_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0301_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0309_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0311_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0313_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0316_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0331_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0334_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0338_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0348_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0350_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0352_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0354_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0362_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0367_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0369_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0372_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0375_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0383_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0387_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0390_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0393_1.txt
#   inflating: MontgomerySet/ClinicalReadings/MCUCXR_0399_1.txt
#    creating: MontgomerySet/CXR_png/
#   inflating: MontgomerySet/CXR_png/MCUCXR_0001_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0002_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0003_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0004_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0005_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0006_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0008_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0011_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0013_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0015_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0016_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0017_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0019_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0020_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0021_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0022_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0023_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0024_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0026_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0027_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0028_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0029_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0030_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0031_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0035_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0038_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0040_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0041_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0042_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0043_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0044_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0045_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0046_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0047_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0048_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0049_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0051_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0052_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0053_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0054_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0055_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0056_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0057_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0058_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0059_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0060_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0061_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0062_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0063_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0064_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0068_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0069_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0070_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0071_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0072_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0074_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0075_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0077_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0079_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0080_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0081_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0082_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0083_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0084_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0085_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0086_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0087_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0089_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0090_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0091_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0092_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0094_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0095_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0096_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0097_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0099_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0100_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0101_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0102_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0103_0.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0104_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0108_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0113_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0117_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0126_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0140_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0141_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0142_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0144_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0150_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0162_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0166_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0170_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0173_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0182_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0188_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0194_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0195_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0196_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0203_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0213_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0218_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0223_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0228_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0243_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0251_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0253_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0254_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0255_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0258_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0264_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0266_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0275_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0282_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0289_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0294_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0301_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0309_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0311_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0313_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0316_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0331_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0334_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0338_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0348_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0350_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0352_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0354_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0362_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0367_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0369_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0372_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0375_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0383_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0387_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0390_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0393_1.png
#   inflating: MontgomerySet/CXR_png/MCUCXR_0399_1.png
#   inflating: MontgomerySet/CXR_png/Thumbs.db
#    creating: MontgomerySet/ManualMask/
#   inflating: MontgomerySet/ManualMask/.DS_Store
#    creating: MontgomerySet/ManualMask/leftMask/
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0001_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0002_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0003_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0004_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0005_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0006_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0008_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0011_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0013_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0015_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0016_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0017_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0019_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0020_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0021_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0022_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0023_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0024_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0026_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0027_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0028_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0029_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0030_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0031_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0035_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0038_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0040_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0041_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0042_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0043_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0044_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0045_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0046_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0047_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0048_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0049_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0051_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0052_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0053_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0054_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0055_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0056_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0057_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0058_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0059_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0060_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0061_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0062_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0063_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0064_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0068_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0069_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0070_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0071_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0072_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0074_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0075_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0077_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0079_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0080_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0081_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0082_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0083_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0084_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0085_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0086_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0087_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0089_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0090_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0091_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0092_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0094_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0095_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0096_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0097_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0099_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0100_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0101_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0102_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0103_0.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0104_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0108_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0113_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0117_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0126_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0140_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0141_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0142_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0144_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0150_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0162_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0166_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0170_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0173_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0182_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0188_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0194_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0195_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0196_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0203_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0213_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0218_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0223_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0228_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0243_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0251_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0253_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0254_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0255_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0258_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0264_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0266_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0275_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0282_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0289_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0294_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0301_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0309_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0311_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0313_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0316_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0331_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0334_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0338_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0348_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0350_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0352_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0354_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0362_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0367_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0369_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0372_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0375_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0383_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0387_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0390_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0393_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/MCUCXR_0399_1.png
#   inflating: MontgomerySet/ManualMask/leftMask/Thumbs.db
#    creating: MontgomerySet/ManualMask/rightMask/
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0001_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0002_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0003_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0004_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0005_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0006_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0008_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0011_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0013_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0015_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0016_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0017_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0019_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0020_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0021_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0022_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0023_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0024_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0026_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0027_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0028_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0029_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0030_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0031_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0035_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0038_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0040_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0041_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0042_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0043_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0044_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0045_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0046_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0047_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0048_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0049_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0051_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0052_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0053_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0054_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0055_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0056_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0057_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0058_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0059_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0060_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0061_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0062_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0063_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0064_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0068_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0069_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0070_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0071_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0072_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0074_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0075_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0077_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0079_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0080_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0081_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0082_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0083_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0084_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0085_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0086_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0087_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0089_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0090_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0091_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0092_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0094_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0095_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0096_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0097_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0099_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0100_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0101_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0102_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0103_0.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0104_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0108_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0113_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0117_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0126_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0140_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0141_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0142_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0144_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0150_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0162_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0166_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0170_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0173_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0182_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0188_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0194_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0195_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0196_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0203_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0213_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0218_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0223_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0228_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0243_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0251_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0253_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0254_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0255_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0258_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0264_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0266_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0275_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0282_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0289_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0294_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0301_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0309_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0311_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0313_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0316_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0331_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0334_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0338_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0348_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0350_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0352_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0354_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0362_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0367_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0369_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0372_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0375_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0383_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0387_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0390_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0393_1.png
#   inflating: MontgomerySet/ManualMask/rightMask/MCUCXR_0399_1.png
#   inflating: MontgomerySet/NLM-MontgomeryCXRSet-ReadMe.pdf

# %%
#Imports
import os
import numpy as np
import cv2
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

# %%
def load_data(path, split=0.1):
    """ 
    Function to read the links of the images in followed by a 
    train-test-split into train, test and validation datasets respectively.
    
    Parameters
      ----------
      path : path to images
          a string containing the path to the directory where images are stored

      split : Ratio of test, train split
          A floating point variable (between 0 and 1) containg the value ratio
          of train and test split of the total images in the ratio 1-split and 
          split respectively

    Returns
      ----------
      data : data split into train, validation, and test
          Returns the dataset split into train, validation, and test with each
          containing the original (input) image, the left lung segmented image
          and the right lung segmented image (outputs)
          
    """

    # Takes the list of original (input) images
    images = sorted(glob(os.path.join(path, "CXR_png", "*.png")))
    # Takes the list of left lung segmented images (output_l)
    masks_l = sorted(glob(os.path.join(path, "ManualMask", "leftMask", "*.png")))
    # Takes the list of right lung segmented images (output_r)
    masks_r = sorted(glob(os.path.join(path, "ManualMask", "rightMask", "*.png")))
    # Using the split ratio to calculate total length in train
    split_size = int(len(images) * split)

    #Splitting images into train and val
    train_x, val_x = train_test_split(images, 
                                      test_size=split_size, 
                                      random_state=42)
    #Splitting left lung into train and val
    train_y_l, val_y_l = train_test_split(masks_l, 
                                          test_size=split_size, 
                                          random_state=42)
    #Splitting images into train and val
    train_y_r, val_y_r = train_test_split(masks_r, 
                                          test_size=split_size, 
                                          random_state=42)
    


    #Splitting train images into train and test
    train_x, test_x = train_test_split(train_x, 
                                       test_size=split_size, 
                                       random_state=42)
    
    #Splitting train left lung segmentation into train and test
    train_y_l, test_y_l = train_test_split(train_y_l, 
                                           test_size=split_size, 
                                           random_state=42)
    
    #Splitting train right lung segmentation into train and test
    train_y_r, test_y_r = train_test_split(train_y_r, 
                                           test_size=split_size, 
                                           random_state=42)

    # Splitted ratios into 81,10,9
    return (train_x, train_y_l, train_y_r), (val_x, val_y_l, val_y_r), (test_x, test_y_l, test_y_r)

# %%
def imageread(path,width=512,height=512):
    """ 
    Function to read the images and to resize them into specified dimensions
    and return the normalized image (pixel values)
    
    Parameters
      ----------
      path : path to images
          a string containing the path to the directory where images are stored

      width : Width dimension of the resized image

      height : Height dimension of the resized image

    Returns
      ----------
      x : Normalized and resized image
          
    """
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (width, height))
    x = x/255.0
    x = x.astype(np.float32)
    return x

# %%
def maskread(path_l, path_r,width=512,height=512):
    """ 
    Function to read the segmented lung images and to resize them into 
    specified dimensions combining the two (left and right segmentation) and 
    return the binarized image (pixel values)
    
    Parameters
      ----------
      path_l : path to images
          a string containing the path to the directory where left lung 
          segmentation images are stored
      
      path_r : path to images
          a string containing the path to the directory where right lung 
          segmentation images are stored

      width : Width dimension of the resized image

      height : Height dimension of the resized image

    Returns
      ----------
      x : Binarized and resized joint image
          
    """
    x_l = cv2.imread(path_l, cv2.IMREAD_GRAYSCALE)
    x_r = cv2.imread(path_r, cv2.IMREAD_GRAYSCALE)
    x = x_l + x_r
    x = cv2.resize(x, (width, height))
    x = x/np.max(x)
    x = x > 0.5
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y_l, y_r):
    """ 
    Function to perform decoding of the image and mask objects, 
    and call above defined operations of decoding and resizing.
    
    Parameters
      ----------
      x : path to images
          a string containing the path to the directory where images are stored
      
      y_l : path to images
          a string containing the path to the directory where left lung 
          segmentation masks are stored

      y_r : path to images
          a string containing the path to the directory where right lung 
          segmentation masks are stored

    Returns
      ----------
      x : Binarized and resized image tensor of required shape
      y : Binarized and resized joint mask tensor of required shape
          
    """
    def _parse(x, y_l, y_r):
        x = x.decode() # convert bytes to string object
        y_l = y_l.decode()
        y_r = y_r.decode()
        x = imageread(x) # read and resize images
        y = maskread(y_l, y_r) # read and resize masks
        return x, y
    x, y = tf.numpy_function(_parse, [x, y_l, y_r], [tf.float32, tf.float32]) # wrap the python function to use it as a tensorflow op.
    x.set_shape([512, 512, 3]) # update the shape of the tensor
    y.set_shape([512, 512, 1])
    return x, y

# %%
def tf_dataset(X, Y_l, Y_r, batch=8):
    """ 
    Function to Prepare the dataset for Training.
    
    Parameters
      ----------
      X : path to images
          a collection of strings containing the path to the directory where images are stored
      
      Y_l : path to images
          a collection of strings containing the path to the directory where left lung 
          segmentation masks are stored

      Y_r : path to images
          a collection of strings containing the path to the directory where right lung 
          segmentation masks are stored

    Returns
      ----------
      dataset : Prepared Dataset object.
          
    """
    dataset = tf.data.Dataset.from_tensor_slices((X, Y_l, Y_r))
    dataset = dataset.shuffle(buffer_size=200)
    dataset = dataset.map(tf_parse) # apply tf_parse to each element in the dataset.
    dataset = dataset.batch(batch) # combine consequitive elements from the dataset into batches
    dataset = dataset.prefetch(buffer_size=4) #allows later elements to be prepared while the current element is being processed
    return dataset

# %% [markdown]
# ## Part 2: Setting up hyperparameters and building the model

# %%
""" Define Training Hyperparameters """
batch_size = 2
lr = 1e-5
epochs = 30
model_path = "/content/model.h5"

# %%
""" Load the Dataset (Training, Validation and Test sets"""
dataset_path = 'MontgomerySet'
(train_x, train_y_l, train_y_r), (val_x, val_y_l, val_y_r), (test_x, test_y_l, test_y_r) = load_data(dataset_path)

# %%
'''Prepare the Training and Validation sets'''
train_dataset = tf_dataset(train_x, train_y_l, train_y_r, batch=batch_size)
val_dataset = tf_dataset(val_x, val_y_l, val_y_r, batch=batch_size)

# %%
""" Defining loss functions and evaluation metrics """
def iou(y_true, y_pred):
    '''
    Function to caluclate the Intersection Over Union (IOU) score 
    between the True Label and Predicted Label.

    Parameters
        ----------
        y_true : True Segmentation Mask in Binary
        
        y_pred : Predicted Segmentation Mask in Binary

      Returns
        ----------
        An IOU score between 0 and 1.
    '''
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32) # Apply the python function as a tensorflow op.

def dice_coef(y_true, y_pred):
    '''
    Function to caluclate the Dice Similarity Coefficient
    between the True Label and Predicted Label.

    Parameters
        ----------
        y_true : True Segmentation Mask in Binary
        
        y_pred : Predicted Segmentation Mask in Binary

      Returns
        ----------
        The Dice Similarity Coefficient between 0 and 1.
    '''
    smooth = 1e-15
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    '''
    Function to caluclate the Dice loss using the Dice Similarity Coefficient
    between the True Label and Predicted Label.

    Parameters
        ----------
        y_true : True Segmentation Mask in Binary
        
        y_pred : Predicted Segmentation Mask in Binary

      Returns
        ----------
        The Dice Loss between 0 and 1.
    '''
    return 1.0 - dice_coef(y_true, y_pred)

# %%
def conv_block(input, num_filters):
    """ 
    Function to build a single Convolution Block consisitng of
    two Conv2D layers, each with Batch Normalisation and Activation layers
    applied consecutively.
    
    Parameters
      ----------
      input : image tensors of appropriate shape.
      
      num_filters : Integer, the dimensionality of the output space 
          (i.e. the number of output filters in the convolution).

    Returns
      ----------
      x : The twice convolved tensor output
          
    """
    x = Conv2D(num_filters, kernel_size=3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, kernel_size=3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(input, num_filters):
    """ 
    Function to build a single Encoder Block consisitng of
    a conv_block and a Max Pooling layer.
    
    Parameters
      ----------
      input : image tensors of appropriate shape.
      
      num_filters : Integer, the dimensionality of the output space 
          (i.e. the number of output filters in the convolution).

    Returns
      ----------
      x : The twice convolved tensor output
      p : Max-pooled output of conv_block
          
    """
    x = conv_block(input, num_filters) # used in the skip connection
    p = MaxPool2D(pool_size=(2, 2))(x)
    return x, p

def decoder_block(input, skip_features, num_filters):
    """ 
    Function to build a single Decoder Block consisitng of
    a transpose operation and a conv_block. We also concatenate the transposed features with
    corresponding features from encoder (skip connection).
    
    Parameters
      ----------
      input : image tensors of appropriate shape.

      skip_features : corresponding feature from encoder.
      
      num_filters : Integer, the dimensionality of the output space 
          (i.e. the number of output filters in the convolution).

    Returns
      ----------
      x : The upsampled output of the decoder block 
          
    """
    x = Conv2DTranspose(num_filters, kernel_size=(2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
def build_unet(input_shape):
    """ 
    Function to build the U-Net model to train.
    
    Parameters
      ----------
      input_shape : shape of input tensor.

    Returns
      ----------
      model : The Model object
          
    """
    inputs = Input(shape=input_shape) # Instantiate tensor with shape of input.

    '''Encoder'''
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    '''Decoder'''
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
'''Define the model and compile with appropriate loss function and optimizer algorithm'''
model = build_unet((512, 512, 3))
'''Set metrics to watch during Training'''
metrics = [dice_coef, iou, Recall(), Precision()]

# In this implememtation we will train the model using the Binary CrossEntropy loss
model.compile(loss='binary_crossentropy', optimizer=Adam(lr), metrics=metrics)

# %%
from tensorflow import keras
keras.utils.plot_model(model, "U-Net.png", show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ## Part 3: Training the model and evaluating it on the test set

# %%
'''Set the callbacks to use during Training'''
callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-8, verbose=1)
        ]

# %%
'''Start the training'''
history = model.fit(
        train_dataset,
        epochs=epochs,
        validation_data=val_dataset,
        callbacks=callbacks
    )
# Out:
# Epoch 1/30
# 56/56 [==============================] - ETA: 0s - loss: 0.6897 - dice_coef: 0.4412 - iou: 0.2857 - recall: 0.9246 - precision: 0.3955
# Epoch 1: val_loss improved from inf to 0.75037, saving model to /content\model.h5
# 56/56 [==============================] - 38s 463ms/step - loss: 0.6897 - dice_coef: 0.4412 - iou: 0.2857 - recall: 0.9246 - precision: 0.3955 - val_loss: 0.7504 - val_dice_coef: 0.3423 - val_iou: 0.2080 - val_recall: 1.0000 - val_precision: 0.2524 - lr: 1.0000e-05
# Epoch 2/30
# 56/56 [==============================] - ETA: 0s - loss: 0.4679 - dice_coef: 0.5478 - iou: 0.3797 - recall: 0.9187 - precision: 0.5812
# Epoch 2: val_loss did not improve from 0.75037
# 56/56 [==============================] - 24s 428ms/step - loss: 0.4679 - dice_coef: 0.5478 - iou: 0.3797 - recall: 0.9187 - precision: 0.5812 - val_loss: 0.7694 - val_dice_coef: 0.3346 - val_iou: 0.2032 - val_recall: 1.0000 - val_precision: 0.2525 - lr: 1.0000e-05
# Epoch 3/30
# 56/56 [==============================] - ETA: 0s - loss: 0.2990 - dice_coef: 0.6569 - iou: 0.4928 - recall: 0.9317 - precision: 0.8239
# Epoch 3: val_loss improved from 0.75037 to 0.73594, saving model to /content\model.h5
# 56/56 [==============================] - 24s 434ms/step - loss: 0.2990 - dice_coef: 0.6569 - iou: 0.4928 - recall: 0.9317 - precision: 0.8239 - val_loss: 0.7359 - val_dice_coef: 0.3264 - val_iou: 0.1978 - val_recall: 0.8664 - val_precision: 0.2937 - lr: 1.0000e-05
# Epoch 4/30
# 56/56 [==============================] - ETA: 0s - loss: 0.2258 - dice_coef: 0.7147 - iou: 0.5600 - recall: 0.9437 - precision: 0.9152
# Epoch 4: val_loss improved from 0.73594 to 0.67099, saving model to /content\model.h5
# 56/56 [==============================] - 24s 423ms/step - loss: 0.2258 - dice_coef: 0.7147 - iou: 0.5600 - recall: 0.9437 - precision: 0.9152 - val_loss: 0.6710 - val_dice_coef: 0.3242 - val_iou: 0.1942 - val_recall: 0.1745 - val_precision: 0.1683 - lr: 1.0000e-05
# Epoch 5/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1823 - dice_coef: 0.7552 - iou: 0.6103 - recall: 0.9546 - precision: 0.9463
# Epoch 5: val_loss improved from 0.67099 to 0.61033, saving model to /content\model.h5
# 56/56 [==============================] - 24s 421ms/step - loss: 0.1823 - dice_coef: 0.7552 - iou: 0.6103 - recall: 0.9546 - precision: 0.9463 - val_loss: 0.6103 - val_dice_coef: 0.2894 - val_iou: 0.1700 - val_recall: 4.5689e-04 - val_precision: 0.0041 - lr: 1.0000e-05
# Epoch 6/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1567 - dice_coef: 0.7824 - iou: 0.6454 - recall: 0.9581 - precision: 0.9589
# Epoch 6: val_loss improved from 0.61033 to 0.58439, saving model to /content\model.h5
# 56/56 [==============================] - 24s 420ms/step - loss: 0.1567 - dice_coef: 0.7824 - iou: 0.6454 - recall: 0.9581 - precision: 0.9589 - val_loss: 0.5844 - val_dice_coef: 0.2458 - val_iou: 0.1411 - val_recall: 2.3251e-05 - val_precision: 7.6617e-04 - lr: 1.0000e-05
# Epoch 7/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1441 - dice_coef: 0.7951 - iou: 0.6626 - recall: 0.9587 - precision: 0.9649
# Epoch 7: val_loss did not improve from 0.58439
# 56/56 [==============================] - 23s 410ms/step - loss: 0.1441 - dice_coef: 0.7951 - iou: 0.6626 - recall: 0.9587 - precision: 0.9649 - val_loss: 0.5901 - val_dice_coef: 0.2253 - val_iou: 0.1271 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-05
# Epoch 8/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1303 - dice_coef: 0.8094 - iou: 0.6832 - recall: 0.9637 - precision: 0.9727
# Epoch 8: val_loss improved from 0.58439 to 0.57333, saving model to /content\model.h5
# 56/56 [==============================] - 24s 419ms/step - loss: 0.1303 - dice_coef: 0.8094 - iou: 0.6832 - recall: 0.9637 - precision: 0.9727 - val_loss: 0.5733 - val_dice_coef: 0.2252 - val_iou: 0.1272 - val_recall: 0.0078 - val_precision: 0.5641 - lr: 1.0000e-05
# Epoch 9/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1191 - dice_coef: 0.8236 - iou: 0.7019 - recall: 0.9684 - precision: 0.9766
# Epoch 9: val_loss improved from 0.57333 to 0.46258, saving model to /content\model.h5
# 56/56 [==============================] - 24s 418ms/step - loss: 0.1191 - dice_coef: 0.8236 - iou: 0.7019 - recall: 0.9684 - precision: 0.9766 - val_loss: 0.4626 - val_dice_coef: 0.3600 - val_iou: 0.2284 - val_recall: 0.1952 - val_precision: 0.9848 - lr: 1.0000e-05
# Epoch 10/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1140 - dice_coef: 0.8297 - iou: 0.7113 - recall: 0.9710 - precision: 0.9769
# Epoch 10: val_loss improved from 0.46258 to 0.34142, saving model to /content\model.h5
# 56/56 [==============================] - 24s 417ms/step - loss: 0.1140 - dice_coef: 0.8297 - iou: 0.7113 - recall: 0.9710 - precision: 0.9769 - val_loss: 0.3414 - val_dice_coef: 0.5345 - val_iou: 0.3684 - val_recall: 0.4538 - val_precision: 0.9924 - lr: 1.0000e-05
# Epoch 11/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1103 - dice_coef: 0.8345 - iou: 0.7178 - recall: 0.9694 - precision: 0.9787
# Epoch 11: val_loss improved from 0.34142 to 0.15539, saving model to /content\model.h5
# 56/56 [==============================] - 24s 418ms/step - loss: 0.1103 - dice_coef: 0.8345 - iou: 0.7178 - recall: 0.9694 - precision: 0.9787 - val_loss: 0.1554 - val_dice_coef: 0.7890 - val_iou: 0.6530 - val_recall: 0.8952 - val_precision: 0.9762 - lr: 1.0000e-05
# Epoch 12/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1067 - dice_coef: 0.8387 - iou: 0.7245 - recall: 0.9722 - precision: 0.9782
# Epoch 12: val_loss improved from 0.15539 to 0.13140, saving model to /content\model.h5
# 56/56 [==============================] - 24s 421ms/step - loss: 0.1067 - dice_coef: 0.8387 - iou: 0.7245 - recall: 0.9722 - precision: 0.9782 - val_loss: 0.1314 - val_dice_coef: 0.8187 - val_iou: 0.6941 - val_recall: 0.9296 - val_precision: 0.9768 - lr: 1.0000e-05
# Epoch 13/30
# 56/56 [==============================] - ETA: 0s - loss: 0.1023 - dice_coef: 0.8429 - iou: 0.7306 - recall: 0.9723 - precision: 0.9817
# Epoch 13: val_loss improved from 0.13140 to 0.12001, saving model to /content\model.h5
# 56/56 [==============================] - 24s 421ms/step - loss: 0.1023 - dice_coef: 0.8429 - iou: 0.7306 - recall: 0.9723 - precision: 0.9817 - val_loss: 0.1200 - val_dice_coef: 0.8233 - val_iou: 0.7029 - val_recall: 0.9331 - val_precision: 0.9855 - lr: 1.0000e-05
# Epoch 14/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0981 - dice_coef: 0.8480 - iou: 0.7381 - recall: 0.9760 - precision: 0.9820
# Epoch 14: val_loss improved from 0.12001 to 0.11581, saving model to /content\model.h5
# 56/56 [==============================] - 24s 421ms/step - loss: 0.0981 - dice_coef: 0.8480 - iou: 0.7381 - recall: 0.9760 - precision: 0.9820 - val_loss: 0.1158 - val_dice_coef: 0.8276 - val_iou: 0.7096 - val_recall: 0.9389 - val_precision: 0.9837 - lr: 1.0000e-05
# Epoch 15/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0947 - dice_coef: 0.8537 - iou: 0.7460 - recall: 0.9770 - precision: 0.9827
# Epoch 15: val_loss improved from 0.11581 to 0.11534, saving model to /content\model.h5
# 56/56 [==============================] - 24s 418ms/step - loss: 0.0947 - dice_coef: 0.8537 - iou: 0.7460 - recall: 0.9770 - precision: 0.9827 - val_loss: 0.1153 - val_dice_coef: 0.8408 - val_iou: 0.7268 - val_recall: 0.9426 - val_precision: 0.9773 - lr: 1.0000e-05
# Epoch 16/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0945 - dice_coef: 0.8536 - iou: 0.7466 - recall: 0.9764 - precision: 0.9820
# Epoch 16: val_loss improved from 0.11534 to 0.11227, saving model to /content\model.h5
# 56/56 [==============================] - 24s 419ms/step - loss: 0.0945 - dice_coef: 0.8536 - iou: 0.7466 - recall: 0.9764 - precision: 0.9820 - val_loss: 0.1123 - val_dice_coef: 0.8220 - val_iou: 0.7033 - val_recall: 0.9388 - val_precision: 0.9813 - lr: 1.0000e-05
# Epoch 17/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0944 - dice_coef: 0.8536 - iou: 0.7466 - recall: 0.9729 - precision: 0.9830
# Epoch 17: val_loss did not improve from 0.11227
# 56/56 [==============================] - 23s 413ms/step - loss: 0.0944 - dice_coef: 0.8536 - iou: 0.7466 - recall: 0.9729 - precision: 0.9830 - val_loss: 0.1143 - val_dice_coef: 0.8365 - val_iou: 0.7214 - val_recall: 0.9558 - val_precision: 0.9640 - lr: 1.0000e-05
# Epoch 18/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0896 - dice_coef: 0.8593 - iou: 0.7550 - recall: 0.9787 - precision: 0.9839
# Epoch 18: val_loss improved from 0.11227 to 0.10920, saving model to /content\model.h5
# 56/56 [==============================] - 24s 423ms/step - loss: 0.0896 - dice_coef: 0.8593 - iou: 0.7550 - recall: 0.9787 - precision: 0.9839 - val_loss: 0.1092 - val_dice_coef: 0.8476 - val_iou: 0.7366 - val_recall: 0.9403 - val_precision: 0.9807 - lr: 1.0000e-05
# Epoch 19/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0865 - dice_coef: 0.8642 - iou: 0.7621 - recall: 0.9801 - precision: 0.9849
# Epoch 19: val_loss improved from 0.10920 to 0.10827, saving model to /content\model.h5
# 56/56 [==============================] - 24s 420ms/step - loss: 0.0865 - dice_coef: 0.8642 - iou: 0.7621 - recall: 0.9801 - precision: 0.9849 - val_loss: 0.1083 - val_dice_coef: 0.8396 - val_iou: 0.7282 - val_recall: 0.9442 - val_precision: 0.9794 - lr: 1.0000e-05
# Epoch 20/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0863 - dice_coef: 0.8631 - iou: 0.7612 - recall: 0.9795 - precision: 0.9851
# Epoch 20: val_loss improved from 0.10827 to 0.10686, saving model to /content\model.h5
# 56/56 [==============================] - 24s 419ms/step - loss: 0.0863 - dice_coef: 0.8631 - iou: 0.7612 - recall: 0.9795 - precision: 0.9851 - val_loss: 0.1069 - val_dice_coef: 0.8331 - val_iou: 0.7183 - val_recall: 0.9496 - val_precision: 0.9770 - lr: 1.0000e-05
# Epoch 21/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0898 - dice_coef: 0.8585 - iou: 0.7560 - recall: 0.9761 - precision: 0.9822
# Epoch 21: val_loss did not improve from 0.10686
# 56/56 [==============================] - 23s 412ms/step - loss: 0.0898 - dice_coef: 0.8585 - iou: 0.7560 - recall: 0.9761 - precision: 0.9822 - val_loss: 0.1241 - val_dice_coef: 0.8403 - val_iou: 0.7287 - val_recall: 0.9682 - val_precision: 0.9417 - lr: 1.0000e-05
# Epoch 22/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0849 - dice_coef: 0.8660 - iou: 0.7654 - recall: 0.9793 - precision: 0.9843
# Epoch 22: val_loss improved from 0.10686 to 0.10377, saving model to /content\model.h5
# 56/56 [==============================] - 24s 420ms/step - loss: 0.0849 - dice_coef: 0.8660 - iou: 0.7654 - recall: 0.9793 - precision: 0.9843 - val_loss: 0.1038 - val_dice_coef: 0.8564 - val_iou: 0.7513 - val_recall: 0.9601 - val_precision: 0.9660 - lr: 1.0000e-05
# Epoch 23/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0817 - dice_coef: 0.8701 - iou: 0.7717 - recall: 0.9805 - precision: 0.9856
# Epoch 23: val_loss did not improve from 0.10377
# 56/56 [==============================] - 23s 414ms/step - loss: 0.0817 - dice_coef: 0.8701 - iou: 0.7717 - recall: 0.9805 - precision: 0.9856 - val_loss: 0.1111 - val_dice_coef: 0.8481 - val_iou: 0.7384 - val_recall: 0.9566 - val_precision: 0.9612 - lr: 1.0000e-05
# Epoch 24/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0815 - dice_coef: 0.8702 - iou: 0.7716 - recall: 0.9799 - precision: 0.9858
# Epoch 24: val_loss did not improve from 0.10377
# 56/56 [==============================] - 23s 413ms/step - loss: 0.0815 - dice_coef: 0.8702 - iou: 0.7716 - recall: 0.9799 - precision: 0.9858 - val_loss: 0.1111 - val_dice_coef: 0.8378 - val_iou: 0.7252 - val_recall: 0.9384 - val_precision: 0.9725 - lr: 1.0000e-05
# Epoch 25/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0803 - dice_coef: 0.8719 - iou: 0.7745 - recall: 0.9808 - precision: 0.9855
# Epoch 25: val_loss did not improve from 0.10377
# 56/56 [==============================] - 23s 413ms/step - loss: 0.0803 - dice_coef: 0.8719 - iou: 0.7745 - recall: 0.9808 - precision: 0.9855 - val_loss: 0.1130 - val_dice_coef: 0.8480 - val_iou: 0.7382 - val_recall: 0.9628 - val_precision: 0.9576 - lr: 1.0000e-05
# Epoch 26/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0802 - dice_coef: 0.8707 - iou: 0.7733 - recall: 0.9802 - precision: 0.9860
# Epoch 26: val_loss improved from 0.10377 to 0.10025, saving model to /content\model.h5
# 56/56 [==============================] - 24s 422ms/step - loss: 0.0802 - dice_coef: 0.8707 - iou: 0.7733 - recall: 0.9802 - precision: 0.9860 - val_loss: 0.1002 - val_dice_coef: 0.8617 - val_iou: 0.7581 - val_recall: 0.9470 - val_precision: 0.9794 - lr: 1.0000e-05
# Epoch 27/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0756 - dice_coef: 0.8778 - iou: 0.7835 - recall: 0.9842 - precision: 0.9872
# Epoch 27: val_loss improved from 0.10025 to 0.09861, saving model to /content\model.h5
# 56/56 [==============================] - 24s 424ms/step - loss: 0.0756 - dice_coef: 0.8778 - iou: 0.7835 - recall: 0.9842 - precision: 0.9872 - val_loss: 0.0986 - val_dice_coef: 0.8542 - val_iou: 0.7482 - val_recall: 0.9390 - val_precision: 0.9859 - lr: 1.0000e-05
# Epoch 28/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0749 - dice_coef: 0.8779 - iou: 0.7840 - recall: 0.9843 - precision: 0.9873
# Epoch 28: val_loss did not improve from 0.09861
# 56/56 [==============================] - 24s 416ms/step - loss: 0.0749 - dice_coef: 0.8779 - iou: 0.7840 - recall: 0.9843 - precision: 0.9873 - val_loss: 0.0994 - val_dice_coef: 0.8561 - val_iou: 0.7532 - val_recall: 0.9428 - val_precision: 0.9828 - lr: 1.0000e-05
# Epoch 29/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0745 - dice_coef: 0.8778 - iou: 0.7844 - recall: 0.9837 - precision: 0.9876
# Epoch 29: val_loss improved from 0.09861 to 0.09717, saving model to /content\model.h5
# 56/56 [==============================] - 24s 424ms/step - loss: 0.0745 - dice_coef: 0.8778 - iou: 0.7844 - recall: 0.9837 - precision: 0.9876 - val_loss: 0.0972 - val_dice_coef: 0.8630 - val_iou: 0.7599 - val_recall: 0.9511 - val_precision: 0.9773 - lr: 1.0000e-05
# Epoch 30/30
# 56/56 [==============================] - ETA: 0s - loss: 0.0720 - dice_coef: 0.8807 - iou: 0.7888 - recall: 0.9858 - precision: 0.9885
# Epoch 30: val_loss did not improve from 0.09717
# 56/56 [==============================] - 24s 418ms/step - loss: 0.0720 - dice_coef: 0.8807 - iou: 0.7888 - recall: 0.9858 - precision: 0.9885 - val_loss: 0.0988 - val_dice_coef: 0.8544 - val_iou: 0.7495 - val_recall: 0.9573 - val_precision: 0.9711 - lr: 1.0000e-05

# %%
from tensorflow.keras.utils import CustomObjectScope

with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef, 'dice_loss': dice_loss}):
  '''
  Under a scope with custom_object_scope(objects_dict), 
  Keras methods such as tf.keras.models.load_model will be able to deserialize any custom object 
  referenced by a saved config (e.g. a custom layer or metric).
  '''
  model = tf.keras.models.load_model("/content/model.h5")

# %%
""" Predicting the mask """
from tqdm import tqdm
import matplotlib.pyplot as plt

ct=0
for x, y_l, y_r in tqdm(zip(test_x, test_y_l, test_y_r), total=len(test_x)):
    """ Extracing the image name. """
    image_name = x.split("/")[-1]

    """ Reading the image """
    ori_x = cv2.imread(x, cv2.IMREAD_COLOR)
    ori_x = cv2.resize(ori_x, (512, 512))
    x = ori_x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)

    """ Reading the mask """
    ori_y_l = cv2.imread(y_l, cv2.IMREAD_GRAYSCALE)
    ori_y_r = cv2.imread(y_r, cv2.IMREAD_GRAYSCALE)
    ori_y = ori_y_l + ori_y_r
    ori_y = cv2.resize(ori_y, (512, 512))
    ori_y = np.expand_dims(ori_y, axis=-1)  ## (512, 512, 1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)  ## (512, 512, 3)

    """ Predicting the mask. """
    y_pred = model.predict(x)[0] > 0.5
    y_pred = y_pred.astype(np.int32)
    #plt.imshow(y_pred)

    """ Saving the predicted mask along with the image and GT """
    save_image_path = str(ct)+".png"
    ct+=1
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    sep_line = np.ones((512, 10, 3)) * 255
    cat_image = np.concatenate([ori_x, sep_line, ori_y, sep_line, y_pred*255], axis=1)
    cv2.imwrite(save_image_path, cat_image)
# Out:
#   0%|                                                                                           | 0/13 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 15ms/step
#   8%|██████▍                                                                            | 1/13 [00:00<00:06,  1.77it/s]
# 1/1 [==============================] - 0s 13ms/step
#  15%|████████████▊                                                                      | 2/13 [00:00<00:04,  2.63it/s]
# 1/1 [==============================] - 0s 14ms/step
#  23%|███████████████████▏                                                               | 3/13 [00:01<00:03,  3.00it/s]
# 1/1 [==============================] - 0s 14ms/step
#  31%|█████████████████████████▌                                                         | 4/13 [00:01<00:02,  3.19it/s]
# 1/1 [==============================] - 0s 14ms/step
#  38%|███████████████████████████████▉                                                   | 5/13 [00:01<00:02,  3.35it/s]
# 1/1 [==============================] - 0s 13ms/step
#  46%|██████████████████████████████████████▎                                            | 6/13 [00:01<00:02,  3.43it/s]
# 1/1 [==============================] - 0s 14ms/step
#  54%|████████████████████████████████████████████▋                                      | 7/13 [00:02<00:01,  3.60it/s]
# 1/1 [==============================] - 0s 12ms/step
#  62%|███████████████████████████████████████████████████                                | 8/13 [00:02<00:01,  3.48it/s]
# 1/1 [==============================] - 0s 14ms/step
#  69%|█████████████████████████████████████████████████████████▍                         | 9/13 [00:02<00:01,  3.42it/s]
# 1/1 [==============================] - 0s 13ms/step
#  77%|███████████████████████████████████████████████████████████████                   | 10/13 [00:03<00:00,  3.47it/s]
# 1/1 [==============================] - 0s 13ms/step
#  85%|█████████████████████████████████████████████████████████████████████▍            | 11/13 [00:03<00:00,  3.43it/s]
# 1/1 [==============================] - 0s 15ms/step
#  92%|███████████████████████████████████████████████████████████████████████████▋      | 12/13 [00:03<00:00,  3.43it/s]
# 1/1 [==============================] - 0s 13ms/step
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:03<00:00,  3.27it/s]
